# %% [markdown]
# # Utiliser l'API Yelp pour obtenir des données

# %% [markdown]
# ## Librairies

# %%
import argparse
import json
import pprint
import requests
import sys
import urllib
import pandas as pd
from urllib.error import HTTPError
from urllib.parse import quote
from urllib.parse import urlencode
from config import API_KEY, client_id # Nos identifiants pour l'API Yelp Fusion
from IPython.display import Image
from IPython.core.display import HTML
import os
from os.path import exists

# %% [markdown]
# ## Constantes

# %%
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'

DEFAULT_TERM = 'bars'
DEFAULT_LOCATION = 'Toulouse'
SEARCH_LIMIT = 50

FILENAME_PHOTOS = "yelp_photos.csv"
FILENAME_REVIEWS = "yelp_reviews.csv"

# %% [markdown]
# ## Fonctions

# %% [markdown]
# Ces fonctions nous serviront à interroger l'api de Yelp, puis à enregistrer les reviews et les url des photos dans les fichiers ```FILENAME_PHOTOS``` et ```FILENAME_REVIEWS```

# %%
def request(host, path, api_key, url_params=None):
    """Étant donné votre API_KEY, envoyez une requête GET à l'API.

    Args:
        host (str): L'hôte de domaine de l'API.
        path (str): Le chemin de l'API après le domaine.
        API_KEY (str): Votre clé API.
        url_params (dict): Un ensemble facultatif de paramètres de requête.

    Returns:
        dict: La réponse JSON de la requête.

    Raises:
        HTTPError: Une erreur se produit à partir de la requête HTTP.
    """
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }

    print(u'Querying {0} ...'.format(url))

    response = requests.request('GET', url, headers=headers, params=url_params)
    
    return response.json()

def request_reviews(host, path, api_key, url_params=None):
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }

    response = requests.request('GET', url, headers=headers, params=url_params)
    
    return response.json()

def search(api_key, term, location, offset=0):
    """Interroger l'API de recherche par un terme de recherche et un emplacement.

    Args:
        term (str): Le terme de recherche transmis à l'API.
        location (str): L'emplacement de recherche transmis à l'API.

    Returns:
        dict: La réponse JSON de la requête.
    """

    url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT,
        'offset': offset
    }
    
    return request(API_HOST, SEARCH_PATH, api_key, url_params=url_params)


def get_business(api_key, business_id):
    """Interroger l'API Business par un ID d'entreprise (business_id).

    Args:
        business_id (str): L'ID de l'entreprise à interroger.

    Returns:
        dict: La réponse JSON de la requête.
    """
    business_path = BUSINESS_PATH + business_id

    return request(API_HOST, business_path, api_key)


def get_reviews(api_key, business_id):
    """Interroger l'API Business par un ID d'entreprise pour obtenir les reviews.

    Args:
        business_id (str): L'ID de l'entreprise à interroger.

    Returns:
        dict: La réponse JSON de la requête.
    """
    business_path = BUSINESS_PATH + business_id+'/reviews'

    return request_reviews(API_HOST, business_path, api_key)

def query_api(term, location):
    """Interroge l'API par les valeurs d'entrée de l'utilisateur.

    Args:
        term (str): Les termes de recherche.
        location (str): L'emplacement de l'entreprise à interroger.
    """
    response = search(API_KEY, term, location)
    
    businesses = response.get('businesses')
    
    print ('Nombre de restaurants :', len(businesses))

    if not businesses:
        print(u'Aucun restaurant trouvé pour {0} dans {1}.'.format(term, location))
        return
    
    ls_business_id = []
    ls_photos_business_id = []
    ls_rating = []
    ls_rev_business_id = []
    ls_photos = [] 
    ls_reviews = []
    for i in range(len(businesses)) :
        business_id = businesses[i]['id']
        response = get_business(API_KEY, business_id)
        ls_business_id.append(business_id)
        
        # récupération des photos
        if "photos" in response:
            photos=response['photos']
            for l in range(len(photos)) :
                ls_photos.append(photos[l])
                ls_photos_business_id.append(business_id)
        else:
            print("Aucune photo pour {}".format(business_id))
        
        # récupération des reviews
        M=get_reviews(API_KEY, business_id)
        if "reviews" in M:
            for j in range (len(M['reviews'])) :
                reviews=M['reviews'][j]['text']
                rating=M['reviews'][j]['rating']
                ls_reviews.append(reviews)
                ls_rating.append(rating)
                ls_rev_business_id.append(business_id)
        else:
            print("Pas de reviews pour {}".format(business_id))

    df_reviews=pd.DataFrame(
        {
            'business_id': ls_rev_business_id, 
            'reviews':ls_reviews, 
            'stars': ls_rating
        }
    )
    df_photos=pd.DataFrame(
        {
            'business_id': ls_photos_business_id, 
            'photos':ls_photos
        }
    )

    df_reviews.to_csv(FILENAME_REVIEWS,index=False)
    df_photos.to_csv(FILENAME_PHOTOS,index=False)
    
    def collect_reviews(
        API_KEY, 
        search_term, 
        location, 
        nb_businesses=200, 
        filename=FILENAME_REVIEWS):
    """ Collecte les reviews avec les critères search_term et location, d'un nombre d'entreprises
    défini par nb_businesses, les sauvegarde dans un fichier csv et retourne un dataframe
    
    Args:
        API_KEY (str): votre clé API
        search_term (str): vos termes de recherche
        location (str): le lieu de la recherche
        nb_businesses (int): nombre d'entreprises dont il faut collecter les reviews
        filename (str): nom du fichier où seront enregistrées les reviews
        
    Returns:
        pandas.DataFrame: les reviews collectées
    """
    offset = 0
    reviews = []
    while offset < nb_businesses:
        yelp_res = search(API_KEY, search_term, location, offset)
        print("Collecte des reviews de {} entreprises...".format(len(yelp_res["businesses"])))
        for business in yelp_res["businesses"]:
            revs = get_reviews(API_KEY, business["id"])
            if "reviews" in [*revs]:
                for rev in revs["reviews"]:
                    review = {
                        "review_id": rev["id"],
                        "user_id": rev["user"]["id"],
                        "business_id": business["id"],
                        "stars": rev["rating"],
                        "text": rev["text"]
                    }
                    reviews.append(review)
        print("{} reviews collectées".format(len(reviews)))        
        offset += SEARCH_LIMIT
    print("Enregistrement de {} reviews dans {}...".format(len(reviews), filename))
    df_reviews = pd.DataFrame(reviews)
    df_reviews.to_csv(filename, index=False)
    if exists("./"+filename):
        print("enregistré avec succès !")
    return df_reviews

# %% [markdown]
# ## Interroger l'API

# %% [markdown]
# ### Collecter les reviews

# %%
def collect_reviews(API_KEY, search_term, location, nb_businesses=200, filename=FILENAME_REVIEWS, filetype="dataframe"):
    offset = 0
    reviews = []
    while offset < nb_businesses:
        yelp_res = search(API_KEY, search_term, location, offset)
        print("Collecte des reviews de {} entreprises...".format(len(yelp_res["businesses"])))
        for business in yelp_res["businesses"]:
            revs = get_reviews(API_KEY, business["id"])
            if "reviews" in [*revs]:
                for rev in revs["reviews"]:
                    review = {
                        "review_id": rev["id"],
                        "user_id": rev["user"]["id"],
                        "business_id": business["id"],
                        "stars": rev["rating"],
                        "text": rev["text"]
                    }
                    reviews.append(review)
        print("{} reviews collectées".format(len(reviews)))        
        offset += SEARCH_LIMIT
    print("Enregistrement de {} reviews dans {}...".format(len(reviews), filename))
    df_reviews = pd.DataFrame(reviews)
    df_reviews.to_csv(filename, index=False)
    if exists("./"+filename):
        print("enregistré avec succès !")
    return df_reviews

# %%
tst_reviews = collect_reviews(API_KEY, "restaurant", "paris")
tst_reviews
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...
# Collecte des reviews de 50 entreprises...
# 150 reviews collectées
# Querying https://api.yelp.com/v3/businesses/search ...
# Collecte des reviews de 50 entreprises...
# 297 reviews collectées
# Querying https://api.yelp.com/v3/businesses/search ...
# Collecte des reviews de 50 entreprises...
# 445 reviews collectées
# Querying https://api.yelp.com/v3/businesses/search ...
# Collecte des reviews de 50 entreprises...
# 588 reviews collectées
# Enregistrement de 588 reviews dans yelp_reviews.csv...
# enregistré avec succès !
#                   review_id                 user_id             business_id  \
# 0    r3bxIJ2ekrp8UPseAj2wjQ  rZ8jfpusbUOn79k8-aM00Q  -0iLH7iQNYtoURciDpJf6w
# 1    SZtFX-6RF0fLrJjFEyM2XQ  auvnv87BU1RnbIvZ2ag8qg  -0iLH7iQNYtoURciDpJf6w
# 2    aGP7nLwEQOUg64jKP8ebsw  1al80cHoRjxr6y2XdH7yyA  -0iLH7iQNYtoURciDpJf6w
# 3    -to6adg_kucf1SgQckgJXw  SRGQPSaj5qy07YcJNbAQfg  IU9_wVOGBKjfqTTpAXpKcQ
# 4    G-YvPO-wUd-NIJDrahcYUg  IZpWaceT5jGXz7DuePadYw  IU9_wVOGBKjfqTTpAXpKcQ
# ..                      ...                     ...                     ...
# 583  mCdNSw81nKEYMVYF4833wA  9YNdR5vC4SFMlzNj7lyMpQ  luWgxwdQDUpURV21UlWslQ
# 584  TB5J08E6r-IkBt5-Ao1nqA  XJDLaoN1PerKw2woiKeepA  luWgxwdQDUpURV21UlWslQ
# 585  YSuuZfpoz6VZi1wPiCWX3A  WsnxtawsIJbNL4wD1oWiAA  luWgxwdQDUpURV21UlWslQ
# 586  7I50BrBghoG_I4SXnlaO7w  34zBgc8h0YybocASWvRXHQ  fJAK_McN2JC_y1uTsYte0w
# 587  4xRJzC8GtaxIiTERVHZvfA  xvu8G900tezTzbbfqmTKvA  fJAK_McN2JC_y1uTsYte0w
#
#      stars                                               text
# 0        5  What an amazing Bistro!! First off, even if yo...
# 1        1  Warning! Tourist trap restaurant.  This restau...
# 2        5  My favorite meal in Paris! \n\nWe started off ...
# 3        5  This is a small bar/restaurant closed to Cathé...
# 4        4  what a wonderful lunch! \nthe decor is so fren...
# ..     ...                                                ...
# 583      5  Our family spent seven days eating our way thr...
# 584      4  A must place to go in Paris. We were excited t...
# 585      3  I've read about their segregation practices an...
# 586      5  Walking into this locale and one is inatantly ...
# 587      5  Less busy than the location in the 9th, but st...
#
# [588 rows x 5 columns]

# %% [markdown]
# Importons les reviews sauvegardées pour vérifier que tout s'est bien passé

# %%
imported_reviews = pd.read_csv("./"+FILENAME_REVIEWS)
imported_reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  r3bxIJ2ekrp8UPseAj2wjQ  rZ8jfpusbUOn79k8-aM00Q  -0iLH7iQNYtoURciDpJf6w
# 1  SZtFX-6RF0fLrJjFEyM2XQ  auvnv87BU1RnbIvZ2ag8qg  -0iLH7iQNYtoURciDpJf6w
# 2  aGP7nLwEQOUg64jKP8ebsw  1al80cHoRjxr6y2XdH7yyA  -0iLH7iQNYtoURciDpJf6w
# 3  -to6adg_kucf1SgQckgJXw  SRGQPSaj5qy07YcJNbAQfg  IU9_wVOGBKjfqTTpAXpKcQ
# 4  G-YvPO-wUd-NIJDrahcYUg  IZpWaceT5jGXz7DuePadYw  IU9_wVOGBKjfqTTpAXpKcQ
#
#    stars                                               text
# 0      5  What an amazing Bistro!! First off, even if yo...
# 1      1  Warning! Tourist trap restaurant.  This restau...
# 2      5  My favorite meal in Paris! \n\nWe started off ...
# 3      5  This is a small bar/restaurant closed to Cathé...
# 4      4  what a wonderful lunch! \nthe decor is so fren...

# %% [markdown]
# ### Collecter les photos

# %%
def collect_photos(
        API_KEY, 
        search_term, 
        location, 
        nb_businesses=200, 
        filename=FILENAME_PHOTOS):
    """ Collecte les photos avec les critères search_term et location, d'un nombre d'entreprises
    défini par nb_businesses, les sauvegarde dans un fichier csv et retourne un dataframe
    
    Args:
        API_KEY (str): votre clé API
        search_term (str): vos termes de recherche
        location (str): le lieu de la recherche
        nb_businesses (int): nombre d'entreprises dont il faut collecter les photos
        filename (str): nom du fichier où seront enregistrées les photos
        
    Returns:
        pandas.DataFrame: les reviews collectées
    """
    offset = 0
    photos = []
    while offset < nb_businesses:
        yelp_res = search(API_KEY, search_term, location, offset)
        print("Collecte des photos de {} entreprises...".format(len(yelp_res["businesses"])))
        for business in yelp_res["businesses"]:
            business = get_business(API_KEY, business["id"])
            if "photos" in [*business]:
                for photo in business["photos"]:
                    photo_entry = {
                        "business_id": business["id"],
                        "photo_url": photo
                    }
                    photos.append(photo_entry)
        print("{} photos collectées".format(len(photos)))        
        offset += SEARCH_LIMIT
    print("Enregistrement de {} photos dans {}...".format(len(photos), filename))
    df_photos = pd.DataFrame(photos)
    df_photos.to_csv(filename, index=False)
    if exists("./"+filename):
        print("enregistré avec succès !")
    return df_photos

# %%
collect_photos(API_KEY, "restaurant", "paris", 200)
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...
# Collecte des photos de 50 entreprises...
# Querying https://api.yelp.com/v3/businesses/-0iLH7iQNYtoURciDpJf6w ...
# Querying https://api.yelp.com/v3/businesses/IU9_wVOGBKjfqTTpAXpKcQ ...
# Querying https://api.yelp.com/v3/businesses/cEjF41ZQB8-SST8cd3EsEw ...
# Querying https://api.yelp.com/v3/businesses/pztzge22A_c_BfzLHCmaMw ...
# Querying https://api.yelp.com/v3/businesses/ctP4c3mwVO5oOzLI48LtuQ ...
# Querying https://api.yelp.com/v3/businesses/70xArgLO0k56YAytyBIHyg ...
# Querying https://api.yelp.com/v3/businesses/WHHt_Jb8Tgidn9mW7oDnIg ...
# Querying https://api.yelp.com/v3/businesses/SkZWjUwmNgcCJJQvgJT1DQ ...
# Querying https://api.yelp.com/v3/businesses/FFz-WusZrBYZexKqhqzCkg ...
# Querying https://api.yelp.com/v3/businesses/_qACPRqSQ6Nvd20H8EY3uw ...
# Querying https://api.yelp.com/v3/businesses/KggnM_Z4wOa_JExunaaWHg ...
# Querying https://api.yelp.com/v3/businesses/DwZsEW-rBrBBLHioGdKoAg ...
# Querying https://api.yelp.com/v3/businesses/ZxtU74SJMRoB8ZQXWwNtRQ ...
# Querying https://api.yelp.com/v3/businesses/PHsKPp496sFZm9K9Xz_TlA ...
# Querying https://api.yelp.com/v3/businesses/flf_IHitjG7bohr-VbOvbA ...
# Querying https://api.yelp.com/v3/businesses/ijqSzadlZ9SCXvUEpMimcA ...
# Querying https://api.yelp.com/v3/businesses/PXYLVsHC33f_dQVVCH-PMw ...
# Querying https://api.yelp.com/v3/businesses/aPLSj-9aNHSQpi7Sf5_9hA ...
# Querying https://api.yelp.com/v3/businesses/-umFmobUgpW_05m_ud1vHw ...
# Querying https://api.yelp.com/v3/businesses/ASbVOR_nTHvwEM9GPTyC0Q ...
# Querying https://api.yelp.com/v3/businesses/Vc-sEV8jnXpHbFeUvP5tLA ...
# Querying https://api.yelp.com/v3/businesses/sFdV05m6Pw5Rw6DdrpQlIw ...
# Querying https://api.yelp.com/v3/businesses/mJMW4j5IYYhbWaBySCPATA ...
# Querying https://api.yelp.com/v3/businesses/XlBCQgnHlYUByBejO8r79g ...
# Querying https://api.yelp.com/v3/businesses/qz7R7oLeEEfvKOlWCxqMVw ...
# Querying https://api.yelp.com/v3/businesses/PGH7BfXz0PNHuwlSt453rA ...
# Querying https://api.yelp.com/v3/businesses/15tUXLav_KIRjszu8IJJ3w ...
# Querying https://api.yelp.com/v3/businesses/eyHbeZgEipcb2QXJF-e_nQ ...
# Querying https://api.yelp.com/v3/businesses/n-XIbgR-Gwb1CqBMyjwj0w ...
# Querying https://api.yelp.com/v3/businesses/n601y41nOORUePsM7KsuaA ...
# Querying https://api.yelp.com/v3/businesses/-y7jgZ3cSCorkeXYGqyweA ...
# Querying https://api.yelp.com/v3/businesses/zj5rGr-hkPjPxM1oxDi3Zg ...
# Querying https://api.yelp.com/v3/businesses/xCkh4Sc0Ih6YAf4hEcrqQA ...
# Querying https://api.yelp.com/v3/businesses/-cSK_-y04p3oVu98DShiyQ ...
# Querying https://api.yelp.com/v3/businesses/QNQ4teRXk5Wx1GFLT3Y9sA ...
# Querying https://api.yelp.com/v3/businesses/zSZ5-zMnusVLLEPOaJasSQ ...
# Querying https://api.yelp.com/v3/businesses/dlFBHdXr7-_6vfB0C-EHvw ...
# Querying https://api.yelp.com/v3/businesses/28m3vU-aLX76lMEyT3WL5Q ...
# Querying https://api.yelp.com/v3/businesses/9Ju4NtzKkV1kXqlDHq5nUg ...
# Querying https://api.yelp.com/v3/businesses/JPSMTwXO8RhjTrCNvdHB3g ...
# Querying https://api.yelp.com/v3/businesses/TWsuxL7J0iACK5KplxZMtA ...
# Querying https://api.yelp.com/v3/businesses/4qTUBV_TXHVZRctoZwr1bg ...
# Querying https://api.yelp.com/v3/businesses/e6RHSG0d94yzA3McN-eFxg ...
# Querying https://api.yelp.com/v3/businesses/RpKOe8ImcDJCgrNL3nhJRQ ...
# Querying https://api.yelp.com/v3/businesses/SILPu61sqx5oTuoyUVK4Tw ...
# Querying https://api.yelp.com/v3/businesses/wLgAxIB7111BcWLWh7KpFw ...
# Querying https://api.yelp.com/v3/businesses/ce3vXRUtUKZjbGf2fv8VzQ ...
# Querying https://api.yelp.com/v3/businesses/4fyyfJ7S8m6TaHL_Ho7mWA ...
# Querying https://api.yelp.com/v3/businesses/UYXnvuOKMQYFdxQL1ZUazw ...
# Querying https://api.yelp.com/v3/businesses/K-cAB9sz9UoopOP0APEi0g ...
# 147 photos collectées
# Querying https://api.yelp.com/v3/businesses/search ...
# Collecte des photos de 50 entreprises...
# Querying https://api.yelp.com/v3/businesses/kYb2q4Li8Cw2PY_I9lCJOw ...
# Querying https://api.yelp.com/v3/businesses/XR5IlJLXRWGBnuuDa1v__g ...
# Querying https://api.yelp.com/v3/businesses/657yy3D4SwyQN3xIjG1Iww ...
# Querying https://api.yelp.com/v3/businesses/dKZo3hRz0sSsQrdahj45uA ...
# Querying https://api.yelp.com/v3/businesses/vjJ5XviPtldKNqAevyoAug ...
# Querying https://api.yelp.com/v3/businesses/2qzLbDM1dkpsKyyCXAEXWw ...
# Querying https://api.yelp.com/v3/businesses/emVjgTi2bjmceJX-ipcL-A ...
# Querying https://api.yelp.com/v3/businesses/V_pVlZDh5vCehaGNugAZNw ...
# Querying https://api.yelp.com/v3/businesses/KglDmt_BDOEqmBjJ8X2bPQ ...
# Querying https://api.yelp.com/v3/businesses/bEvW28II36r2a-L_TWHS7Q ...
# Querying https://api.yelp.com/v3/businesses/NzeX7PR81NRNA0O2Kz-YUQ ...
# Querying https://api.yelp.com/v3/businesses/3K6B3W9N4wUD7l3GT7YUsg ...
# Querying https://api.yelp.com/v3/businesses/XZX3qBgUAcCYGNoIhHGq-g ...
# Querying https://api.yelp.com/v3/businesses/prbkmBK8Uv_UMSBklrNpMQ ...
# Querying https://api.yelp.com/v3/businesses/vEfe8aw5a1UpheitDslyGg ...
# Querying https://api.yelp.com/v3/businesses/c89IQ0D6xXiSMvzLaBJt8Q ...
# Querying https://api.yelp.com/v3/businesses/5oR_HYjo9dJUQCIr9jpzfw ...
# Querying https://api.yelp.com/v3/businesses/J8q2EjxuOk3v19R5xQWAFA ...
# Querying https://api.yelp.com/v3/businesses/CQi4W2vY8KSiG6n24eaScA ...
# Querying https://api.yelp.com/v3/businesses/26Ts-2XRSeqiweSwLuyv6Q ...
# Querying https://api.yelp.com/v3/businesses/qWY5_v3XjhSfaw3KrS9eOg ...
# Querying https://api.yelp.com/v3/businesses/P_mUlHo2-sl7xDJDb5yJQA ...
# Querying https://api.yelp.com/v3/businesses/T_mAHWIXgtMz4YV9cUig1A ...
# Querying https://api.yelp.com/v3/businesses/DS99xpMkcoH9qCkstWmRAw ...
# Querying https://api.yelp.com/v3/businesses/JB7J97Y33N4g3QHP-8xEJA ...
# Querying https://api.yelp.com/v3/businesses/5TbITr_zImkiSc_EWOJkjw ...
# Querying https://api.yelp.com/v3/businesses/pjamP0dgw5Yim3FCpx9WXQ ...
# Querying https://api.yelp.com/v3/businesses/Aq_Bik-n7vJv4IyMPbSo9g ...
# Querying https://api.yelp.com/v3/businesses/B1LO7k6XfAGXLQZ0wCk_3w ...
# Querying https://api.yelp.com/v3/businesses/xEg_qiHxlud17zHXrTrFSQ ...
# Querying https://api.yelp.com/v3/businesses/W0mWaURmq6cA08tNJB43Sg ...
# Querying https://api.yelp.com/v3/businesses/OBQoSZUJZ2OUwcLX-cBNvA ...
# Querying https://api.yelp.com/v3/businesses/4UO8M5flLUR5-TxGdSma0Q ...
# Querying https://api.yelp.com/v3/businesses/bG6jhxY2YhHxD4P63kHD1A ...
# Querying https://api.yelp.com/v3/businesses/cyp5ozhe7ZPf7C_D4nFcjg ...
# Querying https://api.yelp.com/v3/businesses/weiNgy7k32W5fmZoTaF-Bw ...
# Querying https://api.yelp.com/v3/businesses/Xh16xM655GFnFdGAXMGiFQ ...
# Querying https://api.yelp.com/v3/businesses/ldod0YhkG6vfT8Kn-R4Buw ...
# Querying https://api.yelp.com/v3/businesses/rbBs01WKKsVZG61q5IwJ_w ...
# Querying https://api.yelp.com/v3/businesses/PI6edk8v1mpFWpCS56e-0g ...
# Querying https://api.yelp.com/v3/businesses/2cdGE8MLkA30R7ceI5c-Ig ...
# Querying https://api.yelp.com/v3/businesses/_Lcpt3W6ttaIB4uVkBdHVw ...
# Querying https://api.yelp.com/v3/businesses/Vt9_m0v7UyD5HV9s03n_yw ...
# Querying https://api.yelp.com/v3/businesses/XQhDl6ya5GD0o7nf7RRZhw ...
# Querying https://api.yelp.com/v3/businesses/88_DkUZQlKdFM4iXmK0KpA ...
# Querying https://api.yelp.com/v3/businesses/vu19wj42Eq24kZrarm-5zQ ...
# Querying https://api.yelp.com/v3/businesses/tDSgQ7OSjH8t_4CUKF5w2A ...
# Querying https://api.yelp.com/v3/businesses/I9rvKHLA1-EPZw_wswesEA ...
# Querying https://api.yelp.com/v3/businesses/sELjVQsud9aKqLhBC9vNqw ...
# Querying https://api.yelp.com/v3/businesses/r22SOV14alXUSGru9LhIoQ ...
# 294 photos collectées
# Querying https://api.yelp.com/v3/businesses/search ...
# Collecte des photos de 50 entreprises...
# Querying https://api.yelp.com/v3/businesses/zilE2uoIZQ6fpdWGv4mJXw ...
# Querying https://api.yelp.com/v3/businesses/N5d7zQtjOKbDqPsFRu2EjA ...
# Querying https://api.yelp.com/v3/businesses/N3zQ7Y52QXRnfQy_Gri3yw ...
# Querying https://api.yelp.com/v3/businesses/Bn1ea1dkZZKvKIx-ju8sjw ...
# Querying https://api.yelp.com/v3/businesses/K_GEE-rokTt1u1OORgu1tw ...
# Querying https://api.yelp.com/v3/businesses/MfmIKDTvTNfpdID38qWVag ...
# Querying https://api.yelp.com/v3/businesses/hfe0QLfHwyaiE_HBhkq9AA ...
# Querying https://api.yelp.com/v3/businesses/Erdi9jgM4Wrw8e_uwTY47Q ...
# Querying https://api.yelp.com/v3/businesses/Hxqo84j1PWvo0-HizpHsuA ...
# Querying https://api.yelp.com/v3/businesses/sgc5fGdiYfOmq8sTeyG3Kw ...
# Querying https://api.yelp.com/v3/businesses/RIVd8n0kAZedJLD4-eFZ2g ...
# Querying https://api.yelp.com/v3/businesses/XqOlA1nGHcwiMmU2QDtdBQ ...
# Querying https://api.yelp.com/v3/businesses/26YjCdVvyn5jv4sZYd1Lvw ...
# Querying https://api.yelp.com/v3/businesses/prSiklkzkMYOPs7IoONtjA ...
# Querying https://api.yelp.com/v3/businesses/3drmuEM-hbUqOXVmZRtF4g ...
# Querying https://api.yelp.com/v3/businesses/-sggfLHsfPbgXw5S6a7Jdg ...
# Querying https://api.yelp.com/v3/businesses/5jviAXLXm5E78wlpE0pTxA ...
# Querying https://api.yelp.com/v3/businesses/AKjVaoytS_XrHBPX7iJeBQ ...
# Querying https://api.yelp.com/v3/businesses/Tp528C9RQ-8lpT66KtPJ0A ...
# Querying https://api.yelp.com/v3/businesses/BvC_O7iWXp9vVTSBKxmMPA ...
# Querying https://api.yelp.com/v3/businesses/eV3XeyDMWwT0E8o8nYodRQ ...
# Querying https://api.yelp.com/v3/businesses/Df7eNm_K1CwYy4E18vRzFw ...
# Querying https://api.yelp.com/v3/businesses/nB_9kzgII13vfX6LNAdi9g ...
# Querying https://api.yelp.com/v3/businesses/TYDSdXOJU-07rZgRFdZYEA ...
# Querying https://api.yelp.com/v3/businesses/u0lE065YXe5sKcDiAzJcHg ...
# Querying https://api.yelp.com/v3/businesses/1_Oc_w2U7dKw8tu8_cfjsQ ...
# Querying https://api.yelp.com/v3/businesses/VcZ_db1U796FnxNBoiYl-w ...
# Querying https://api.yelp.com/v3/businesses/R3bELm2-TJPBNu3Y9edaGA ...
# Querying https://api.yelp.com/v3/businesses/Y9olNhl_2mLe-pex8Y5qiQ ...
# Querying https://api.yelp.com/v3/businesses/vCy73lpmXz0Pa4BuEyPzUg ...
# Querying https://api.yelp.com/v3/businesses/QczhiTpJ8eN22wwxNK6LxA ...
# Querying https://api.yelp.com/v3/businesses/u0PQ2A4w14iMWrrk5pWGUA ...
# Querying https://api.yelp.com/v3/businesses/hJIZV85BqdcNXA2Nh9WLCQ ...
# Querying https://api.yelp.com/v3/businesses/9ACptOR-HKm38LCwSXILgA ...
# Querying https://api.yelp.com/v3/businesses/OBlZC2T9theJFTjovK4hdQ ...
# Querying https://api.yelp.com/v3/businesses/UukMgqeP0Uhk4B0VHWNeGw ...
# Querying https://api.yelp.com/v3/businesses/J6ge-0l4EFj5pXuPQRj58g ...
# Querying https://api.yelp.com/v3/businesses/skkSs9EZUiQeMVxEEkjIqA ...
# Querying https://api.yelp.com/v3/businesses/hl4K9f9X_VhgEkDH9cdiwg ...
# Querying https://api.yelp.com/v3/businesses/3cNLpk5HmmnXptjwg-KN-w ...
# Querying https://api.yelp.com/v3/businesses/vatPhRbtUkYxSeiZ-ev2wQ ...
# Querying https://api.yelp.com/v3/businesses/zs91nh7MtFUQcr2mE26EqQ ...
# Querying https://api.yelp.com/v3/businesses/oBry7omEm5kavp_l86AjCA ...
# Querying https://api.yelp.com/v3/businesses/WqXhQg1Nhv4pffAHp-3JyA ...
# Querying https://api.yelp.com/v3/businesses/-JX9WdcLezp4g6Ts8SG8qg ...
# Querying https://api.yelp.com/v3/businesses/YTI4rZRObDfFcSDkZ9lu3w ...
# Querying https://api.yelp.com/v3/businesses/kGCB1YFIkkeOMN4Yh8iUXQ ...
# Querying https://api.yelp.com/v3/businesses/3Mg4L7o7Og9aajb7tee2sQ ...
# Querying https://api.yelp.com/v3/businesses/vf0SfwWuKbwmJJvtmzAKcg ...
# Querying https://api.yelp.com/v3/businesses/fK5KhHO8az5LVmzOPsED2g ...
# 438 photos collectées
# Querying https://api.yelp.com/v3/businesses/search ...
# Collecte des photos de 50 entreprises...
# Querying https://api.yelp.com/v3/businesses/v5Noospim4MQhncZRpCuCA ...
# Querying https://api.yelp.com/v3/businesses/RcODJWKhY2jJGNoXK8e9xQ ...
# Querying https://api.yelp.com/v3/businesses/OQp17JUwTt26gHc7mhKO9g ...
# Querying https://api.yelp.com/v3/businesses/VvW6OwWXbDrtUBlfiqhDTg ...
# Querying https://api.yelp.com/v3/businesses/69Jp-YKmgfan9SWC36zgxA ...
# Querying https://api.yelp.com/v3/businesses/WGm2729Xmwt0XJvRq0lN3w ...
# Querying https://api.yelp.com/v3/businesses/MsDztnnHceaGNZ2sfw6ThQ ...
# Querying https://api.yelp.com/v3/businesses/ZISkD_hIHSJgmFHKp33mVg ...
# Querying https://api.yelp.com/v3/businesses/GBfg0200_34Wiu9em7a6jg ...
# Querying https://api.yelp.com/v3/businesses/jbBCAq2FOumM7nn9vEjpsA ...
# Querying https://api.yelp.com/v3/businesses/JiOnwN1bQsT8sBUKs4qoKA ...
# Querying https://api.yelp.com/v3/businesses/bnFogmIGrX00dxEaUJFmQw ...
# Querying https://api.yelp.com/v3/businesses/dxcHp_NAnO2e_BvR_pY4Nw ...
# Querying https://api.yelp.com/v3/businesses/-YKc0e0z_47s8JeXA2feOg ...
# Querying https://api.yelp.com/v3/businesses/keMX4xNwB_Rv0ASj0DSd1A ...
# Querying https://api.yelp.com/v3/businesses/eoUCWArm9w8kXtyA0N7MoQ ...
# Querying https://api.yelp.com/v3/businesses/cEixu9Rr6e7j5IIsspU9QQ ...
# Querying https://api.yelp.com/v3/businesses/j2mUHWVXSKSkEuHJao_wKg ...
# Querying https://api.yelp.com/v3/businesses/LwRrembo4omcYIColDl12A ...
# Querying https://api.yelp.com/v3/businesses/tM2GensNFi0OjEDhrbA4TQ ...
# Querying https://api.yelp.com/v3/businesses/DK98pb7ExxYUlAEfFJ3w1Q ...
# Querying https://api.yelp.com/v3/businesses/XNfpjD7KWU-r1jB1SR3alg ...
# Querying https://api.yelp.com/v3/businesses/PUmsiCvU9a8gYgt06aoAdQ ...
# Querying https://api.yelp.com/v3/businesses/y_-CiNR-pEGMiZk_aPeQmg ...
# Querying https://api.yelp.com/v3/businesses/4OEhHYGyNN5DIxpdSTUy_A ...
# Querying https://api.yelp.com/v3/businesses/kdVwJe2eBVgKeeVu99hArQ ...
# Querying https://api.yelp.com/v3/businesses/2JpBWCr2q4934qvRK9WTEw ...
# Querying https://api.yelp.com/v3/businesses/Z5axFBqFr1WeUc2UjLW5Ww ...
# Querying https://api.yelp.com/v3/businesses/plA1PYIoNhrR7uJO_essiQ ...
# Querying https://api.yelp.com/v3/businesses/R44YZMAdHQFB9BCIUcwnhA ...
# Querying https://api.yelp.com/v3/businesses/lvP5_4OHw_tdo_gqfXViig ...
# Querying https://api.yelp.com/v3/businesses/vAfDke0aeT1tNnpKu4-UrA ...
# Querying https://api.yelp.com/v3/businesses/xKH01fpVnNP-HNjnt1R9dA ...
# Querying https://api.yelp.com/v3/businesses/RMawY4F3XYXgFS8tDqIGRg ...
# Querying https://api.yelp.com/v3/businesses/GQkhUv3Vu8PVEfq913LNhg ...
# Querying https://api.yelp.com/v3/businesses/TNTEFv9yIM6CQDa5vVmoJg ...
# Querying https://api.yelp.com/v3/businesses/0oMvjqVdNPIS81x79amvAA ...
# Querying https://api.yelp.com/v3/businesses/fD2daNgOHoQe4Ny48ULlEQ ...
# Querying https://api.yelp.com/v3/businesses/XWa3IcDRMD18mHaM-qHifQ ...
# Querying https://api.yelp.com/v3/businesses/JzwEHzNpDBFawqKvujirvQ ...
# Querying https://api.yelp.com/v3/businesses/Tb6siRZNm2X7GLiPXWpLLg ...
# Querying https://api.yelp.com/v3/businesses/Mx5eTETDjUN9bZ1CfTEWAw ...
# Querying https://api.yelp.com/v3/businesses/lhsLzC6sfkEBtuQ323YdYw ...
# Querying https://api.yelp.com/v3/businesses/YHW32SOHWdY7UvRSWhSf2w ...
# Querying https://api.yelp.com/v3/businesses/i9yOyX3pVBLLuiISazJK2A ...
# Querying https://api.yelp.com/v3/businesses/36bmPjOYLp6-Ql_IEiSQUw ...
# Querying https://api.yelp.com/v3/businesses/uvSAEMJdnE62BiOuxn_W4Q ...
# Querying https://api.yelp.com/v3/businesses/5PPRzntCCI_2wIp0g3SWwQ ...
# Querying https://api.yelp.com/v3/businesses/luWgxwdQDUpURV21UlWslQ ...
# Querying https://api.yelp.com/v3/businesses/MqdwabesLORy1qtSiv2NKA ...
# 582 photos collectées
# Enregistrement de 582 photos dans yelp_photos.csv...
# enregistré avec succès !
#                 business_id                                          photo_url
# 0    -0iLH7iQNYtoURciDpJf6w  https://s3-media2.fl.yelpcdn.com/bphoto/czh2IE...
# 1    -0iLH7iQNYtoURciDpJf6w  https://s3-media2.fl.yelpcdn.com/bphoto/Y0D70M...
# 2    -0iLH7iQNYtoURciDpJf6w  https://s3-media2.fl.yelpcdn.com/bphoto/TtMQlD...
# 3    IU9_wVOGBKjfqTTpAXpKcQ  https://s3-media4.fl.yelpcdn.com/bphoto/J9RByC...
# 4    IU9_wVOGBKjfqTTpAXpKcQ  https://s3-media4.fl.yelpcdn.com/bphoto/Y5fZV7...
# ..                      ...                                                ...
# 577  luWgxwdQDUpURV21UlWslQ  https://s3-media4.fl.yelpcdn.com/bphoto/G5h7Af...
# 578  luWgxwdQDUpURV21UlWslQ  https://s3-media1.fl.yelpcdn.com/bphoto/-821dW...
# 579  MqdwabesLORy1qtSiv2NKA  https://s3-media3.fl.yelpcdn.com/bphoto/vkgbLl...
# 580  MqdwabesLORy1qtSiv2NKA  https://s3-media3.fl.yelpcdn.com/bphoto/IDs9Qp...
# 581  MqdwabesLORy1qtSiv2NKA  https://s3-media3.fl.yelpcdn.com/bphoto/x57RBh...
#
# [582 rows x 2 columns]

# %% [markdown]
# Importons les photos sauvegardées:

# %%
imported_photos = pd.read_csv("./"+FILENAME_PHOTOS)
imported_photos.head()
# Out:
#               business_id                                          photo_url
# 0  -0iLH7iQNYtoURciDpJf6w  https://s3-media2.fl.yelpcdn.com/bphoto/czh2IE...
# 1  -0iLH7iQNYtoURciDpJf6w  https://s3-media2.fl.yelpcdn.com/bphoto/Y0D70M...
# 2  -0iLH7iQNYtoURciDpJf6w  https://s3-media2.fl.yelpcdn.com/bphoto/TtMQlD...
# 3  IU9_wVOGBKjfqTTpAXpKcQ  https://s3-media4.fl.yelpcdn.com/bphoto/J9RByC...
# 4  IU9_wVOGBKjfqTTpAXpKcQ  https://s3-media4.fl.yelpcdn.com/bphoto/Y5fZV7...

# %%
for i in range(10):
    print("business_id : {}".format(imported_photos.iloc[i]["business_id"]))
    display(Image(url=imported_photos.iloc[i]["photo_url"]))
# Out:
# business_id : -0iLH7iQNYtoURciDpJf6w
# <img src="https://s3-media2.fl.yelpcdn.com/bphoto/czh2IEUeT5FnYko4QgUP8A/o.jpg"/>
# business_id : -0iLH7iQNYtoURciDpJf6w
# <img src="https://s3-media2.fl.yelpcdn.com/bphoto/Y0D70Mjn25o7lPMwqLhYHg/o.jpg"/>
# business_id : -0iLH7iQNYtoURciDpJf6w
# <img src="https://s3-media2.fl.yelpcdn.com/bphoto/TtMQlDyy7QUF4fDaxvqljg/o.jpg"/>
# business_id : IU9_wVOGBKjfqTTpAXpKcQ
# <img src="https://s3-media4.fl.yelpcdn.com/bphoto/J9RByC4HuTubBKX77PYeEg/o.jpg"/>
# business_id : IU9_wVOGBKjfqTTpAXpKcQ
# <img src="https://s3-media4.fl.yelpcdn.com/bphoto/Y5fZV7nTccxCc6cVfPTmOg/o.jpg"/>
# business_id : IU9_wVOGBKjfqTTpAXpKcQ
# <img src="https://s3-media1.fl.yelpcdn.com/bphoto/hPCZTbuWGgjBvMsB2unxWg/o.jpg"/>
# business_id : cEjF41ZQB8-SST8cd3EsEw
# <img src="https://s3-media3.fl.yelpcdn.com/bphoto/mVwgxgmpUcAUOZKdxypwSw/o.jpg"/>
# business_id : cEjF41ZQB8-SST8cd3EsEw
# <img src="https://s3-media4.fl.yelpcdn.com/bphoto/816RjJqKuAcGtiJfft4J3A/o.jpg"/>
# business_id : cEjF41ZQB8-SST8cd3EsEw
# <img src="https://s3-media2.fl.yelpcdn.com/bphoto/azxglNBbUKqPl0GDE4GzNw/o.jpg"/>
# business_id : pztzge22A_c_BfzLHCmaMw
# <img src="https://s3-media4.fl.yelpcdn.com/bphoto/rOSDujQ3Oy4pts4FiVpe7Q/o.jpg"/>
